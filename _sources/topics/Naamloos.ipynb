# %%
print(waarde)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b5f2e3e5613a> in <module>
# ----> 1 print(waarde)
#
# NameError: name 'waarde' is not defined

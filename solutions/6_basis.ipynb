# %% [markdown]
# # Basis

# %% [markdown]
# ## Functie 1
#
# Schrijf een Python functie num_to_base_b(number, base), die een (niet negatieve) integer number en een grondtal base (van 2 tot en met 10) accepteert en een string teruggeeft die het getal number in grondtal base voorstelt.

# %% [markdown]
# ```python
# def num_to_base_b(number, base):
#     result = ""
#     while number > 0:
#         result = str(number % base) + result
#         number = number // base
#     return result
# ```

# %% [markdown]
# ## Functie 2
#
# Daarom ga je een Python functie `base_b_to_num(string, base)` schrijven die een string `string` en een grondtal `base` accepteert, waarbij `string` een getal in grondtal `base` voorstelt en `base` een getal van 2 tot en met 10 is. De functie `base_b_to_num` moet een integer in grondtal 10 teruggeven die hetzelfde getal voorstelt als `string`.

# %% [markdown]
# ```python
# def base_b_to_num(string, base):
#     result = 0
#     for i in range(0, len(string)):
#         result = result + (int(string[-1]) * base ** i)
#         string = string[:-1]
#     return result
# ```

# %% [markdown]
# ## Functie 3

# %% [markdown]
# Nu kunnen we wat we geschreven hebben samenvoegen tot een functie base_to_base(b1, b2, s_in_b1) die drie argumenten accepteert, een grondtal b1, een grondtal b2 (beide met een waarde tussen 2 tot en met 10) en s_in_b1, wat een string is die een getal in grondtal b1 voorstelt.
#
# De functie base_to_base moet een string teruggeven die dezelfde waarde in grondtal b2 vertegenwoordigt.

# %% [markdown]
# ```python
# def base_to_base(b1, b2, s_in_b1):
#     num = base_b_to_num(s_in_b1, b1)
#     return num_to_base_b(num, b2)
# ```

# %% [markdown]
# ## Functie 4
# Schrijf een functie add(s, t) die twee binaire strings s en t accepteert en hun som als resultaat teruggeeft terugstuurt, ook als binaire string.

# %% [markdown]
# ```python
# def add(s, t):
#     num1 = base_b_to_num(s, 2)
#     num2 = base_b_to_num(t, 2)
#     num = num1 + num2
#     return num_to_base_b(num, 2)
# ```
